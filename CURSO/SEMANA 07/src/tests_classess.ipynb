# %%
from model_inference import ModelInferece
from model_training import ModelTraining
from experiments import Experiments
from visualization import Visualization
from data_source import DataSource

# %%
model_value, model_name = Experiments().run_experiment()
print(f'Best model is {model_name}, Error mean ABS is {model_value}')
# Out:
# Reading Data
# Preprocessing Data
# Creating DataFrame for Data Manipulation
# Droping columns with missing values
# Dropping column with id
# Creating list with numeric features
# Creating list with categoric features
# Removing target
# Feature encoder
# Feature Normalization and enconding
# Processing Test Data
# Creating DataFrame for Data Manipulation
# Droping columns with missing values
# Dropping column with id
# Creating list with numeric features
# Creating list with categoric features
# Removing target
# Feature encoder
# Feature Normalization and enconding
# Training Model
# Treinando o modelo  linear
# LinearRegression()
# Treinando o modelo  ridge
# Ridge()
# Treinando o modelo  decision_tree
# DecisionTreeRegressor()
# Treinando o modelo  random_forest
# RandomForestRegressor()
# Treinando o modelo  svm
# SVR()
# Treinando o modelo  catboost
# ...
# Learning rate set to 0.04175
# 0:	learn: 77625.9139040	total: 49.7ms	remaining: 49.6s
# ...

# %%
model = ModelTraining().model_training(model_name)
# Out:
# Loading Data
# Training preprocessing
# Creating DataFrame for Data Manipulation
# Droping columns with missing values
# Dropping column with id
# Creating list with numeric features
# Creating list with categoric features
# Removing target
# Feature encoder
# Feature Normalization and enconding
# Training model
# ...

# %%
y_pred, y_true = ModelInferece().predict()
# Out:
# Loading the model
# Loading data
# Preprocessing data
# Creating DataFrame for Data Manipulation
# Droping columns with missing values
# Dropping column with id
# Creating list with numeric features
# Creating list with categoric features
# Removing target
# Feature encoder
# Feature Normalization and enconding
# MSZoning         0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# ExterQual        0
# ExterCond        0
# Foundation       0
# Heating          0
# HeatingQC        0
# CentralAir       0
# KitchenQual      0
# Functional       0
# PavedDrive       0
# SaleType         0
# SaleCondition    0
# MSSubClass       0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# ...

# %%
Visualization().regression_viz(y_true['SalePrice'], y_pred, 'saida')
# Out:
# /home/cassio/PycharmProjects/acelera-dev/venv/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
y_pred
# Out:
# array([163004.63360876, 163011.81999237, 163028.0398376 , ...,
#        163014.41728015, 163009.83707468, 163018.97654215])
